# %% [markdown]
# Topics:
# 1. Creating Object
#     - pd.Series(list)
#     - pd.DataFrame(data, columns, index)
#     - df.dtypes
#
#
# 2. Viewing Data
#     - df.head()
#     - df.tail()
#
#     - df.index
#     - df.columns
#     - df.describe()
#     - df.T
#     - len(df)
#     - df.shape
#
#     - df.sort_index(axis=1, ascending=True)
#     - df.sort_values(by=col_name, ascending=True)
#
#
# 3. Selecting Data
#     - df[col_name]
#     - df[slicing rows]
#
#     - df.loc[label]
#     - df.loc[multi_rows, multi_cols]
#     - df.at[row, col]
#     - df.iloc[row_positions, col_position]
#     - df.iat[row_i, col_j]
#
#     - df[df['A'] > 0]
#     - df[df > 0]
#     - df[df['A'].isin(list)]
#
#     - df.at[row_i, col_j] = 0
#     - df.iat[i, j] = 0
#     - df.loc[:, col_name] = np.array(list)
#
#
# 4. Missing Data
#     - df.dropna(how='any')
#     - df.fillna(value=x)
#     - pd.isna(df)
#
#
# 5. Operations
#     - df.mean(axis=0/1)
#     - s.shift(n)
#     - df.sub(s, axis='index')
#     - df.apply(f)
#         - df.apply(np.cumsum)
#     - s.Value_counts()
#     - s.str.lower()
#
#
# 6. Merge
#     - pd.concat(pieces)
#     - pd.merge(df1, df2, on='key')
#
#
# 7. Grouping
#     - df.groupby(col).sum()
#     - df.groupby(lisf_of_cols).sum()
#
#
# 8. Reshapnig & Categorizing
#     - df.stack()
#     - df.unstack()
#     - pd.pivot_table(df, values, index, columns)
#
#     - df[name] = df[col_name].stype("category")
#     - df[name].cat.categories = [.....]
#     - df[name] = df[name].cat.set_categories([.....])
#     - df.sort_values(by=name)
#     - df.groupby(name).size()
#
#
# 9. Plotting
#     - s.plot()
#     - df.plot()
#
#
# 10. Data in/out
#     - df.to_csv(filename, 'df')
#     - pd.read_csv(filename)
#
#     - df.to_excel(filename, sheet_name='sheet1')
#     - pd.read_excel(filename, ....)
#
#     - pd.to_hdf(filename, 'df')
#     - pd.read_hdf(filename, 'df')
#
#     - pd.HDFStore(filename)

# %% [markdown]
# Acknowledge:
#
# The exmaples and fellow took from the link: https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html#operations
